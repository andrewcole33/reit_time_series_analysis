# %%
from module import decomposition
from module import dickey_fuller
from module import arima_endog
from module import arima_exog
from module import rmse_cv
from module import lasso_reg


import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from numpy import hstack
import warnings
import os
from fredapi import Fred
warnings.filterwarnings('ignore')

import itertools
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
import pmdarima as pm
from pmdarima import model_selection

from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# %matplotlib inline
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Set Datetime

# %%
start = datetime(2000,2,1)
end = datetime(2020,1,31)

# %% [markdown]
# ## Gather Endogenous Data

# %%
AMT = web.DataReader('AMT', 'av-daily', start = start, end = end, api_key = 'Y8YQFOIVHPA381U4')
AMT = AMT.copy()
AMT.index = pd.to_datetime(AMT.index)
AMT = AMT.resample('MS').mean()
AMT['mid'] = (AMT['high']+AMT['low'])/2
AMT.drop(labels = ['high', 'low', 'open', 'close', 'volume'], axis = 1, inplace = True)
AMT.to_csv('data/mid_prices/AMT_mid.csv')

# %%
plt.style.use('ggplot')
AMT.plot(figsize = (16,4))
plt.xlabel('Month')
plt.ylabel('Mid Price')
plt.title('AMT Mid Price Time Series')
plt.tight_layout()
plt.show();

# %% [markdown]
# ## Perform Decomposition of Time Series

# %%
decomposition(AMT)

# %%
AMT_diff = AMT.diff(periods = 1).dropna()

# %%
dickey_fuller(AMT_diff)
# Out:
# The series passes the Dickey Fuller Test for Stationarity. P-Value = 1.25394302812834e-05

# %%
plot_pacf(AMT_diff);

# %%
plot_acf(AMT_diff);

# %%
parameters = (3,1,2)
seasonal_parameters = (3,1,2,12)

# %% [markdown]
# ## Train Test Split

# %%
AMT_train = AMT[:'2015']
AMT_test = AMT['2016':]

# %% [markdown]
# ## SARIMAX Model (No Exogenous Variables)

# %%
arima_endog(AMT_train, AMT, parameters, seasonal_parameters)
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  191
# Model:             SARIMAX(3, 1, 2)x(3, 1, 2, 12)   Log Likelihood                -318.319
# Date:                            Mon, 10 Feb 2020   AIC                            660.638
# Time:                                    09:46:39   BIC                            695.852
# Sample:                                02-01-2000   HQIC                           674.948
#                                      - 12-01-2015
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift          0.0003      0.001      0.424      0.672      -0.001       0.002
# ar.L1          0.2935      0.762      0.385      0.700      -1.199       1.786
# ar.L2          0.1173      0.607      0.193      0.847      -1.072       1.306
# ar.L3          0.1264      0.115      1.095      0.273      -0.100       0.353
# ma.L1         -0.2338      0.771     -0.303      0.762      -1.745       1.277
# ma.L2         -0.2345      0.606     -0.387      0.699      -1.423       0.954
# ar.S.L12      -0.6726      0.806     -0.834      0.404      -2.253       0.907
# ar.S.L24      -0.2356      0.224     -1.051      0.293      -0.675       0.204
# ar.S.L36      -0.1055      0.168     -0.628      0.530      -0.435       0.224
# ma.S.L12      -0.3425      0.803     -0.427      0.670      -1.916       1.231
# ma.S.L24      -0.3694      0.730     -0.506      0.613      -1.800       1.061
# sigma2         5.4433      0.754      7.223      0.000       3.966       6.920
# ===================================================================================
# Ljung-Box (Q):                       28.72   Jarque-Bera (JB):                54.55
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.57   Skew:                            -1.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Predictions vs. Observed:

# %%
parameters = (4,1,3)
seasonal_parameters = (4,1,3,12)

# %%
arima_endog(AMT_train, AMT, parameters, seasonal_parameters)
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  191
# Model:             SARIMAX(4, 1, 3)x(4, 1, 3, 12)   Log Likelihood                -291.454
# Date:                            Mon, 10 Feb 2020   AIC                            614.908
# Time:                                    09:47:21   BIC                            660.289
# Sample:                                02-01-2000   HQIC                           633.345
#                                      - 12-01-2015
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift          0.0003      0.001      0.353      0.724      -0.001       0.002
# ar.L1         -0.2045      1.827     -0.112      0.911      -3.785       3.376
# ar.L2          0.3621      1.009      0.359      0.720      -1.615       2.339
# ar.L3          0.4218      0.502      0.841      0.401      -0.562       1.405
# ar.L4          0.1112      0.352      0.316      0.752      -0.578       0.801
# ma.L1          0.1958      1.809      0.108      0.914      -3.349       3.741
# ma.L2         -0.4986      1.048     -0.476      0.634      -2.553       1.556
# ma.L3         -0.3357      0.629     -0.534      0.594      -1.569       0.897
# ar.S.L12      -1.0987      0.630     -1.743      0.081      -2.334       0.137
# ar.S.L24      -0.7827      0.637     -1.228      0.219      -2.032       0.466
# ar.S.L36      -0.3236      0.280     -1.156      0.248      -0.873       0.225
# ar.S.L48      -0.1036      0.149     -0.693      0.488      -0.396       0.189
# ma.S.L12      -0.0396      0.662     -0.060      0.952      -1.338       1.259
# ma.S.L24      -0.3625      0.597     -0.607      0.544      -1.533       0.808
# ma.S.L36      -0.4010      0.665     -0.603      0.547      -1.704       0.903
# sigma2         5.5887      1.731      3.228      0.001       2.195       8.982
# ===================================================================================
# Ljung-Box (Q):                       27.10   Jarque-Bera (JB):                39.54
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.94   Skew:                            -0.95
# Prob(H) (two-sided):                  0.03   Kurtosis:                         4.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Predictions vs. Observed:

# %% [markdown]
# ## Gather Exogenous Variables

# %%
AMT_rates = pd.read_csv('data/AMT_rates.csv', index_col = 'date')

# %% [markdown]
# ### Train Test Split Exogenous Variables

# %% [markdown]
# ### Perform Lasso Regression

# %%
lasso_reg(AMT_rates)
# Out:
# The R-score of the Lasso Regression is: 0.9889717801393691
#
# usd1mtd156n       0.000000
# mortgage30us     -0.000000
# mortgage15us     -0.000000
# dcpf3m           -0.000000
# cpn3m             0.000000
# dcpf1m            0.000000
# aaa               0.000000
# baa               0.000000
# dff               0.000000
# flexsc            0.000000
# t10y2y            0.000000
# t10y3m           -0.000000
# tedrate          -0.000000
# t10yff           -0.000000
# t5yff            -0.000000
# tb6smffm         -0.000000
# usd3mtd156n      -0.000000
# usd12md156n      -0.000000
# eur1wkd156n       0.000000
# mprime            0.000000
# tb3ms             0.000000
# dtb6             -0.000000
# dgs10             0.000000
# dgs3mo            0.000000
# dexuseu           0.000000
# dexchus          -0.000000
# dexusuk          -0.000000
# dexsius          -0.000000
# nasdaqcom         0.010890
# willreitind       0.001919
# willlrgcap        0.003302
# willsmlcap       -0.002159
# vxdcls           -0.046691
# stlfsi           -0.000000
# nfci              0.000000
# h8b3094ncba      -0.000029
# bc0dcbw027nbog   -0.003022
# casdcbw027nbog   -0.011039
# cildcbw027nbog    0.061687
# dpsdcbw027nbog   -0.002449
# rhedcbw027nbog    0.083074
# clsacbw027nbog    0.023862
# dpsacbw027nbog    0.006619
# relacbw027nbog    0.005833
# rheacbw027nbog   -0.025168
# tlaacbw027nbog    0.003170
# tlbacbw027nbog   -0.000006
# totci            -0.036929
# usepuindxd        0.038052
# wlemuindxd        0.001696
# emvfincrises     -0.000000
# stlppm           -0.000000
# dtype: float64
#
# Lasso picked 20 variables and eliminated the other 32 variables

# %% [markdown]
# ### Select significant exogenous features from Lasso Regression

# %%
AMT_rates_train = AMT_rates[:'2016']
AMT_rates_test = AMT_rates['2016':]

# %%
exog_train = AMT_rates_train[['nasdaqcom', 'willreitind', 'willlrgcap', 'willsmlcap', 'vxdcls', 'h8b3094ncba', 'bc0dcbw027nbog', 'casdcbw027nbog', 'cildcbw027nbog','dpsdcbw027nbog', 
                  'rhedcbw027nbog', 'clsacbw027nbog', 'dpsacbw027nbog', 'relacbw027nbog', 'rheacbw027nbog', 'tlaacbw027nbog', 'tlbacbw027nbog', 'totci', 'usepuindxd', 'wlemuindxd']]

# %%
exog_test = AMT_rates_test[['nasdaqcom', 'willreitind', 'willlrgcap', 'willsmlcap', 'vxdcls', 'h8b3094ncba', 'bc0dcbw027nbog', 'casdcbw027nbog', 'cildcbw027nbog','dpsdcbw027nbog', 
                  'rhedcbw027nbog', 'clsacbw027nbog', 'dpsacbw027nbog', 'relacbw027nbog', 'rheacbw027nbog', 'tlaacbw027nbog', 'tlbacbw027nbog', 'totci', 'usepuindxd', 'wlemuindxd']]

# %%
AMT_train.shape, exog_train.shape
# Out:
# ((191, 1), (191, 20))

# %%
AMT_test.shape, exog_test.shape
# Out:
# ((49, 1), (49, 20))

# %%
arima_model = sm.tsa.statespace.SARIMAX(AMT_train,
                                        exog = exog_train,
                                        order = parameters,
                                        seasonal_order = seasonal_parameters,
                                        enforce_stationarity = False,
                                        enforce_invertability = False,
                                        trend = 't')
results = arima_model.fit()
print(f'Summary: {results.summary()}')
print()
print('Diagnostics: ')
results.plot_diagnostics(figsize = (15,8))
plt.show()
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  191
# Model:             SARIMAX(4, 1, 3)x(4, 1, 3, 12)   Log Likelihood                -272.122
# Date:                            Mon, 10 Feb 2020   AIC                            616.244
# Time:                                    09:44:55   BIC                            718.350
# Sample:                                02-01-2000   HQIC                           657.727
#                                      - 12-01-2015
# Covariance Type:                              opg
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Prob(H) (two-sided):                  0.04   Kurtosis:                         3.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:

# %%
predictions = results.get_prediction(start = pd.to_datetime('2015-01-01'), end = pd.to_datetime('2020-01-01'), dynamic=True, exog = exog_test)
pred_conf = predictions.conf_int()
    
#Plot observed values
ax = AMT['2011-02-01':].plot(label='observed', figsize = (10,5))

#Plot predicted values
predictions.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9, color = 'darkblue')

#Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='lightblue', alpha=.7)

#Set axes labels
ax.set_xlabel('Year')
ax.set_ylabel('Mid Price')
plt.legend(loc = 'best')
plt.title(f'Mid Price Over Time')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Auto - ARIMA

# %%
full_exog = exog_train.append(exog_test)

# %%
ts = AMT

auto_arima = auto_arima = pm.auto_arima(ts, 
                      exogenous = full_exog,
                      error_action='ignore', trace=True,
                      suppress_warnings=True, d =1,
                      seasonal=True, m=12,
                      start_p=0, start_q=0,
                      start_P=0, start_Q=0,
                      stationary=False,
                      with_intercept=False, 
                      D = 12, trend = 't')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-96-17d2062e3012> in <module>
#      10                       stationary=False,
#      11                       with_intercept=False,
# ---> 12                       D = 12, trend = 't')
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pmdarima/arima/auto.py in auto_arima(y, exogenous, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     577
#     578         # do the step-through...
# --> 579         all_res = stepwise_wrapper.solve_stepwise()
#     580
#     581     # filter the non-successful ones
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pmdarima/arima/_auto_solvers.py in solve_stepwise(self)
#     175
#     176         # fit a baseline p, d, q model
# --> 177         self._do_fit((p, d, q), (P, D, Q, m))
#     178
#     179         # null model with possible constant
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pmdarima/arima/_auto_solvers.py in _do_fit(self, order, seasonal_order, constant)
#     156                 order=order,
#     157                 seasonal_order=seasonal_order,
# --> 158                 with_intercept=constant)
#     159
#     160             # use the orders as a key to be hashed for
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pmdarima/arima/_auto_solvers.py in _fit_arima(x, xreg, order, seasonal_order, start_params, trend, method, maxiter, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, **kwargs)
#     351                     scoring_args=scoring_args,
#     352                     with_intercept=with_intercept, **kwargs)\
# --> 353             .fit(x, exogenous=xreg, **fit_params)
#     354
#     355     # for non-stationarity errors or singular matrices, return None
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pmdarima/arima/arima.py in fit(self, y, exogenous, **fit_args)
#     463
#     464         # Internal call
# --> 465         self._fit(y, exogenous, **fit_args)
#     466
#     467         # now make a forecast if we're validating to compute the
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pmdarima/arima/arima.py in _fit(self, y, exogenous, **fit_args)
#     387             with warnings.catch_warnings(record=False):
#     388                 warnings.simplefilter('ignore')
# --> 389                 fit, self.arima_res_ = _fit_wrapper()
#     390         else:
#     391             fit, self.arima_res_ = _fit_wrapper()
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pmdarima/arima/arima.py in _fit_wrapper()
#     381                                     maxiter=_maxiter,
#     382                                     disp=disp,
# --> 383                                     **fit_args)
#     384
#     385         # sometimes too many warnings...
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/statespace/mlemodel.py in fit(self, start_params, transformed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, **kwargs)
#     480                                            full_output=full_output,
#     481                                            disp=disp, callback=callback,
# --> 482                                            skip_hessian=True, **kwargs)
#     483
#     484         # Just return the fitted parameters if requested
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     468                                                        callback=callback,
#     469                                                        retall=retall,
# --> 470                                                        full_output=full_output)
#     471
#     472         # NOTE: this is for fit_regularized and should be generalized
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     217                             disp=disp, maxiter=maxiter, callback=callback,
#     218                             retall=retall, full_output=full_output,
# --> 219                             hess=hessian)
#     220
#     221         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     437                                      callback=callback, args=fargs,
#     438                                      bounds=bounds, disp=disp,
# --> 439                                      **extra_kwargs)
#     440
#     441     if full_output:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     289         def func_and_grad(x):
#     290             f = fun(x, *args)
# --> 291             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     292             return f, g
#     293     else:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/optimize/optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     695         ei[k] = 1.0
#     696         d = epsilon * ei
# --> 697         df = (f(*((xk + d,) + args)) - f0) / d[k]
#     698         if not np.isscalar(df):
#     699             try:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/base/model.py in f(params, *args)
#     442
#     443         def f(params, *args):
# --> 444             return -self.loglike(params, *args) / nobs
#     445
#     446         if method == 'newton':
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/statespace/mlemodel.py in loglike(self, params, *args, **kwargs)
#     657             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     658
# --> 659         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     660
#     661         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/statespace/kalman_filter.py in loglike(self, **kwargs)
#     873                                ' MEMORY_NO_LIKELIHOOD option is selected.')
#     874         kwargs['conserve_memory'] = MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD
# --> 875         kfilter = self._filter(**kwargs)
#     876         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     877                                         self.loglikelihood_burn)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/statespace/kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     800
#     801         # Run the filter
# --> 802         kfilter()
#     803
#     804         return kfilter
#
# KeyboardInterrupt:
