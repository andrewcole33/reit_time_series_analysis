# %%
from module import decomposition
from module import dickey_fuller
from module import arima_endog
from module import arima_exog
from module import rmse_cv
from module import lasso_reg


import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from numpy import hstack
import warnings
import os
from fredapi import Fred
warnings.filterwarnings('ignore')

import itertools
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
import pmdarima as pm
from pmdarima import model_selection

from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# %matplotlib inline
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Set Datetime

# %%
start = datetime(2000,2,1)
end = datetime(2020,1,31)

# %% [markdown]
# ## Gather Endogenous Data

# %%
AMT = web.DataReader('AMT', 'av-daily', start = start, end = end, api_key = 'Y8YQFOIVHPA381U4')
AMT = AMT.copy()
AMT.index = pd.to_datetime(AMT.index)
AMT = AMT.resample('MS').mean()
AMT['mid'] = (AMT['high']+AMT['low'])/2
AMT.drop(labels = ['high', 'low', 'open', 'close', 'volume'], axis = 1, inplace = True)

# %%
plt.style.use('ggplot')
AMT.plot(figsize = (16,4))
plt.xlabel('Month')
plt.ylabel('Mid Price')
plt.title('AMT Mid Price Time Series')
plt.tight_layout()
plt.show();

# %% [markdown]
# ## Perform Decomposition of Time Series

# %%
decomposition(AMT)

# %%
AMT_diff = AMT.diff(periods = 1).dropna()

# %%
dickey_fuller(AMT_diff)
# Out:
# The series passes the Dickey Fuller Test for Stationarity. P-Value = 1.2693061998954238e-05

# %%
plot_pacf(AMT_diff);

# %%
plot_acf(AMT_diff);

# %%
parameters = (3,1,2)
seasonal_parameters = (3,1,2,12)

# %% [markdown]
# ## Train Test Split

# %%
AMT_train = AMT[:'2015']
AMT_test = AMT['2016':]

# %% [markdown]
# ## SARIMAX Model (No Exogenous Variables)

# %%
arima_endog(AMT_train, parameters, seasonal_parameters)
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  191
# Model:             SARIMAX(3, 1, 2)x(3, 1, 2, 12)   Log Likelihood                -318.140
# Date:                            Fri, 07 Feb 2020   AIC                            660.280
# Time:                                    17:39:20   BIC                            695.494
# Sample:                                02-01-2000   HQIC                           674.590
#                                      - 12-01-2015
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift          0.0003      0.001      0.438      0.661      -0.001       0.001
# ar.L1          0.3107      0.656      0.474      0.636      -0.975       1.596
# ar.L2          0.1202      0.539      0.223      0.823      -0.936       1.176
# ar.L3          0.1473      0.110      1.339      0.181      -0.068       0.363
# ma.L1         -0.2653      0.662     -0.400      0.689      -1.564       1.033
# ma.L2         -0.2467      0.538     -0.459      0.647      -1.301       0.808
# ar.S.L12      -0.6744      0.813     -0.830      0.407      -2.267       0.919
# ar.S.L24      -0.1909      0.230     -0.831      0.406      -0.641       0.259
# ar.S.L36      -0.0799      0.172     -0.465      0.642      -0.417       0.257
# ma.S.L12      -0.3435      0.807     -0.426      0.670      -1.926       1.239
# ma.S.L24      -0.4133      0.756     -0.546      0.585      -1.896       1.069
# sigma2         5.3588      0.775      6.914      0.000       3.840       6.878
# ===================================================================================
# Ljung-Box (Q):                       28.09   Jarque-Bera (JB):                52.60
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.66   Skew:                            -1.01
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Predictions vs. Observed:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Future Forecast:

# %% [markdown]
# ## Gather Exogenous Variables

# %%
AMT_rates = pd.read_csv('data/AMT_rates.csv', index_col = 'date')

# %% [markdown]
# ### Train Test Split Exogenous Variables

# %% [markdown]
# ### Perform Lasso Regression

# %%
lasso_reg(AMT_rates)
# Out:
# The R-score of the Lasso Regression is: 0.9889717801393691
#
# usd1mtd156n       0.000000
# mortgage30us     -0.000000
# mortgage15us     -0.000000
# dcpf3m           -0.000000
# cpn3m             0.000000
# dcpf1m            0.000000
# aaa               0.000000
# baa               0.000000
# dff               0.000000
# flexsc            0.000000
# t10y2y            0.000000
# t10y3m           -0.000000
# tedrate          -0.000000
# t10yff           -0.000000
# t5yff            -0.000000
# tb6smffm         -0.000000
# usd3mtd156n      -0.000000
# usd12md156n      -0.000000
# eur1wkd156n       0.000000
# mprime            0.000000
# tb3ms             0.000000
# dtb6             -0.000000
# dgs10             0.000000
# dgs3mo            0.000000
# dexuseu           0.000000
# dexchus          -0.000000
# dexusuk          -0.000000
# dexsius          -0.000000
# nasdaqcom         0.010890
# willreitind       0.001919
# willlrgcap        0.003302
# willsmlcap       -0.002159
# vxdcls           -0.046691
# stlfsi           -0.000000
# nfci              0.000000
# h8b3094ncba      -0.000029
# bc0dcbw027nbog   -0.003022
# casdcbw027nbog   -0.011039
# cildcbw027nbog    0.061687
# dpsdcbw027nbog   -0.002449
# rhedcbw027nbog    0.083074
# clsacbw027nbog    0.023862
# dpsacbw027nbog    0.006619
# relacbw027nbog    0.005833
# rheacbw027nbog   -0.025168
# tlaacbw027nbog    0.003170
# tlbacbw027nbog   -0.000006
# totci            -0.036929
# usepuindxd        0.038052
# wlemuindxd        0.001696
# emvfincrises     -0.000000
# stlppm           -0.000000
# dtype: float64
#
# Lasso picked 20 variables and eliminated the other 32 variables

# %% [markdown]
# ### Select significant exogenous features from Lasso Regression

# %%
AMT_rates_train = AMT_rates[:'2016']
AMT_rates_test = AMT_rates['2016':]

# %%
exog_train = AMT_rates_train[['nasdaqcom', 'willreitind', 'willlrgcap', 'willsmlcap', 'vxdcls', 'h8b3094ncba', 'bc0dcbw027nbog', 'casdcbw027nbog', 'cildcbw027nbog','dpsdcbw027nbog', 
                  'rhedcbw027nbog', 'clsacbw027nbog', 'dpsacbw027nbog', 'relacbw027nbog', 'rheacbw027nbog', 'tlaacbw027nbog', 'tlbacbw027nbog', 'totci', 'usepuindxd', 'wlemuindxd']]

# %%
exog_test = AMT_rates_test[['nasdaqcom', 'willreitind', 'willlrgcap', 'willsmlcap', 'vxdcls', 'h8b3094ncba', 'bc0dcbw027nbog', 'casdcbw027nbog', 'cildcbw027nbog','dpsdcbw027nbog', 
                  'rhedcbw027nbog', 'clsacbw027nbog', 'dpsacbw027nbog', 'relacbw027nbog', 'rheacbw027nbog', 'tlaacbw027nbog', 'tlbacbw027nbog', 'totci', 'usepuindxd', 'wlemuindxd']]

# %%
AMT_train.shape, exog_train.shape
# Out:
# ((191, 1), (191, 20))

# %%
AMT_test.shape, exog_test.shape
# Out:
# ((49, 1), (49, 20))

# %%
arima_model = sm.tsa.statespace.SARIMAX(AMT_train,
                                        exog = exog_train,
                                        order = parameters,
                                        seasonal_order = seasonal_parameters,
                                        enforce_stationarity = False,
                                        enforce_invertability = False,
                                        trend = 't')
results = arima_model.fit()
print(f'Summary: {results.summary()}')
print()
print('Diagnostics: ')
results.plot_diagnostics(figsize = (15,8))
plt.show()
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  191
# Model:             SARIMAX(3, 1, 2)x(3, 1, 2, 12)   Log Likelihood                -295.663
# Date:                            Fri, 07 Feb 2020   AIC                            655.327
# Time:                                    17:57:07   BIC                            749.230
# Sample:                                02-01-2000   HQIC                           693.486
#                                      - 12-01-2015
# Covariance Type:                              opg
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# drift             -0.0015      0.009     -0.170      0.865      -0.019       0.016
# nasdaqcom          0.0103      0.011      0.935      0.350      -0.011       0.032
# willreitind        0.0037      0.002      2.127      0.033       0.000       0.007
# willlrgcap         0.0009      0.001      0.646      0.518      -0.002       0.004
# willsmlcap        -0.0008      0.001     -1.420      0.155      -0.002       0.000
# vxdcls            -0.1091      0.177     -0.618      0.537      -0.456       0.237
# h8b3094ncba    -3.161e-06   1.58e-05     -0.200      0.841   -3.41e-05    2.78e-05
# bc0dcbw027nbog     0.0090      0.022      0.406      0.685      -0.034       0.052
# casdcbw027nbog     0.0037      0.014      0.264      0.792      -0.024       0.031
# cildcbw027nbog    -0.0005      0.117     -0.004      0.997      -0.230       0.229
# dpsdcbw027nbog     0.0022      0.017      0.132      0.895      -0.031       0.036
# rhedcbw027nbog    -1.2649      4.257     -0.297      0.766      -9.609       7.079
# clsacbw027nbog    -0.0136      0.024     -0.564      0.573      -0.061       0.034
# dpsacbw027nbog    -0.0063      0.013     -0.471      0.637      -0.032       0.020
# relacbw027nbog    -0.0148      0.028     -0.538      0.590      -0.069       0.039
# rheacbw027nbog     1.2508      4.285      0.292      0.770      -7.147       9.649
# tlaacbw027nbog     0.0169      0.037      0.457      0.648      -0.056       0.090
# tlbacbw027nbog    -0.0160      0.039     -0.412      0.680      -0.092       0.060
# totci              0.0120      0.093      0.129      0.898      -0.171       0.195
# usepuindxd         0.0090      0.017      0.539      0.590      -0.024       0.042
# wlemuindxd         0.0059      0.010      0.569      0.569      -0.014       0.026
# ar.L1             -0.4856      5.199     -0.093      0.926     -10.675       9.704
# ar.L2             -0.1834      2.777     -0.066      0.947      -5.626       5.259
# ar.L3              0.0389      0.747      0.052      0.958      -1.426       1.503
# ma.L1              0.5817      5.223      0.111      0.911      -9.656      10.819
# ma.L2              0.0571      3.263      0.017      0.986      -6.337       6.452
# ar.S.L12          -0.6653      0.548     -1.214      0.225      -1.740       0.409
# ar.S.L24          -0.3384      0.325     -1.042      0.298      -0.975       0.298
# ar.S.L36          -0.2747      0.209     -1.313      0.189      -0.685       0.135
# ma.S.L12          -0.1166      0.568     -0.205      0.837      -1.230       0.997
# ma.S.L24          -0.2239      0.456     -0.491      0.623      -1.118       0.670
# sigma2             5.9234      1.324      4.473      0.000       3.328       8.519
# ===================================================================================
# Ljung-Box (Q):                       39.71   Jarque-Bera (JB):                 0.34
# Prob(Q):                              0.48   Prob(JB):                         0.84
# Heteroskedasticity (H):               1.88   Skew:                            -0.08
# Prob(H) (two-sided):                  0.03   Kurtosis:                         3.17
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:

# %%
predictions = results.get_prediction(start = pd.to_datetime('2015-01-01'), end = pd.to_datetime('2020-01-01'), dynamic=True, exog = exog_test)
pred_conf = predictions.conf_int()
    
#Plot observed values
ax = AMT['2011-02-01':].plot(label='observed', figsize = (10,5))

#Plot predicted values
predictions.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9, color = 'darkblue')

#Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='lightblue', alpha=.7)

#Set axes labels
ax.set_xlabel('Year')
ax.set_ylabel('Mid Price')
plt.legend(loc = 'best')
plt.title(f'Mid Price Over Time')
plt.tight_layout()
plt.show()
