# %%
from module import decomposition
from module import dickey_fuller
from module import arima_endog
from module import arima_exog
from module import rmse_cv
from module import lasso_reg


import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from numpy import hstack
import warnings
import os
from fredapi import Fred
warnings.filterwarnings('ignore')

import itertools
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
import pmdarima as pm
from pmdarima import model_selection

from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# %matplotlib inline
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Set Datetime

# %%
start = datetime(2000,2,1)
end = datetime(2020,1,31)

# %% [markdown]
# ## Gather Endogenous Data

# %%
AMT = web.DataReader('AMT', 'av-daily', start = start, end = end, api_key = 'Y8YQFOIVHPA381U4')
AMT = AMT.copy()
AMT.index = pd.to_datetime(AMT.index)
AMT = AMT.resample('MS').mean()
AMT['mid'] = (AMT['high']+AMT['low'])/2
AMT.drop(labels = ['high', 'low', 'open', 'close', 'volume'], axis = 1, inplace = True)
AMT.to_csv('data/mid_prices/AMT_mid.csv')

# %%
plt.style.use('ggplot')
AMT.plot(figsize = (10,5))
plt.xlabel('Month')
plt.ylabel('Mid Price')
plt.title('AMT Mid Price Time Series')
plt.tight_layout()
plt.show();

# %% [markdown]
# ## Perform Decomposition of Time Series

# %%
decomposition(AMT)

# %%
AMT_diff = AMT.diff(periods = 1).dropna()

# %%
dickey_fuller(AMT_diff)
# Out:
# The series passes the Dickey Fuller Test for Stationarity. P-Value = 1.2420595615535548e-05

# %%
plot_pacf(AMT_diff);

# %%
plot_acf(AMT_diff);

# %%
parameters = (11,1,2)
seasonal_parameters = (11,1,2,12)

# %% [markdown]
# ## Train Test Split

# %%
AMT_train = AMT[:'2017']
AMT_test = AMT['2018':]

# %% [markdown]
# ## SARIMAX Model (No Exogenous Variables)

# %%
arima_endog(AMT_train, AMT, parameters, seasonal_parameters)
# Out:
# Summary:                                   Statespace Model Results
# ============================================================================================
# Dep. Variable:                                  mid   No. Observations:                  215
# Model:             SARIMAX(11, 1, 2)x(11, 1, 2, 12)   Log Likelihood                -153.542
# Date:                              Tue, 11 Feb 2020   AIC                            363.085
# Time:                                      11:33:36   BIC                            421.256
# Sample:                                  02-01-2000   HQIC                           385.793
#                                        - 12-01-2017
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift          0.0056      0.018      0.317      0.751      -0.029       0.040
# ar.L1          0.0766      2.150      0.036      0.972      -4.138       4.291
# ar.L2          0.0314      1.920      0.016      0.987      -3.731       3.794
# ar.L3          0.0692      0.456      0.152      0.879      -0.825       0.964
# ar.L4         -0.0792      0.361     -0.219      0.826      -0.787       0.629
# ar.L5          0.0347      0.381      0.091      0.927      -0.712       0.781
# ar.L6         -0.3180      0.247     -1.286      0.198      -0.802       0.167
# ar.L7         -0.1408      0.661     -0.213      0.831      -1.436       1.154
# ar.L8          0.1845      0.705      0.262      0.794      -1.198       1.567
# ar.L9         -0.1249      0.525     -0.238      0.812      -1.154       0.904
# ar.L10        -0.1303      0.492     -0.265      0.791      -1.095       0.834
# ar.L11         0.0034      0.437      0.008      0.994      -0.853       0.860
# ma.L1          0.0846      2.110      0.040      0.968      -4.052       4.221
# ma.L2         -0.1364      1.911     -0.071      0.943      -3.882       3.609
# ar.S.L12      -1.2265      0.719     -1.706      0.088      -2.635       0.182
# ar.S.L24      -1.2823      1.107     -1.158      0.247      -3.452       0.887
# ar.S.L36      -0.8721      1.140     -0.765      0.444      -3.107       1.362
# ar.S.L48      -0.6939      0.946     -0.733      0.463      -2.548       1.160
# ar.S.L60      -0.9756      0.889     -1.098      0.272      -2.718       0.766
# ar.S.L72      -0.7877      1.015     -0.776      0.438      -2.777       1.201
# ar.S.L84      -0.6176      1.175     -0.526      0.599      -2.920       1.685
# ar.S.L96      -0.3533      1.217     -0.290      0.772      -2.738       2.032
# ar.S.L108     -0.3530      1.134     -0.311      0.756      -2.576       1.870
# ar.S.L120     -0.9996      0.736     -1.358      0.174      -2.442       0.443
# ar.S.L132     -0.2051      0.380     -0.539      0.590      -0.950       0.540
# ma.S.L12       0.5351      1.024      0.522      0.601      -1.472       2.543
# ma.S.L24      -0.1771      0.894     -0.198      0.843      -1.930       1.576
# sigma2        10.2400      7.867      1.302      0.193      -5.179      25.659
# ===================================================================================
# Ljung-Box (Q):                       25.61   Jarque-Bera (JB):                 1.41
# Prob(Q):                              0.96   Prob(JB):                         0.49
# Heteroskedasticity (H):               1.09   Skew:                             0.07
# Prob(H) (two-sided):                  0.85   Kurtosis:                         2.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Predictions vs. Observed:

# %% [markdown]
# #### Gather Exogenous Variables

# %%
AMT_rates = pd.read_csv('data/AMT_rates.csv', index_col = 'date')

# %% [markdown]
# ### Perform Lasso Regression

# %%
lasso_reg(AMT_rates)
# Out:
# The R-score of the Lasso Regression is: 0.9889717801393691
#
# usd1mtd156n       0.000000
# mortgage30us     -0.000000
# mortgage15us     -0.000000
# dcpf3m           -0.000000
# cpn3m             0.000000
# dcpf1m            0.000000
# aaa               0.000000
# baa               0.000000
# dff               0.000000
# flexsc            0.000000
# t10y2y            0.000000
# t10y3m           -0.000000
# tedrate          -0.000000
# t10yff           -0.000000
# t5yff            -0.000000
# tb6smffm         -0.000000
# usd3mtd156n      -0.000000
# usd12md156n      -0.000000
# eur1wkd156n       0.000000
# mprime            0.000000
# tb3ms             0.000000
# dtb6             -0.000000
# dgs10             0.000000
# dgs3mo            0.000000
# dexuseu           0.000000
# dexchus          -0.000000
# dexusuk          -0.000000
# dexsius          -0.000000
# nasdaqcom         0.010890
# willreitind       0.001919
# willlrgcap        0.003302
# willsmlcap       -0.002159
# vxdcls           -0.046691
# stlfsi           -0.000000
# nfci              0.000000
# h8b3094ncba      -0.000029
# bc0dcbw027nbog   -0.003022
# casdcbw027nbog   -0.011039
# cildcbw027nbog    0.061687
# dpsdcbw027nbog   -0.002449
# rhedcbw027nbog    0.083074
# clsacbw027nbog    0.023862
# dpsacbw027nbog    0.006619
# relacbw027nbog    0.005833
# rheacbw027nbog   -0.025168
# tlaacbw027nbog    0.003170
# tlbacbw027nbog   -0.000006
# totci            -0.036929
# usepuindxd        0.038052
# wlemuindxd        0.001696
# emvfincrises     -0.000000
# stlppm           -0.000000
# dtype: float64
#
# Lasso picked 20 variables and eliminated the other 32 variables

# %% [markdown]
# ### Select significant exogenous features from Lasso Regression

# %%
AMT_rates_train = AMT_rates[:'2018']
AMT_rates_test = AMT_rates['2018':]

# %%
exog_train2 = AMT_rates_train[['rhedcbw027nbog', 'cildcbw027nbog', 'usepuindxd', 'clsacbw027nbog', 'vxdcls', 'totci', 'rheacbw027nbog', 'casdcbw027nbog']]

# %%
exog_test2 = AMT_rates_test[['rhedcbw027nbog', 'cildcbw027nbog', 'usepuindxd', 'clsacbw027nbog', 'vxdcls', 'totci', 'rheacbw027nbog', 'casdcbw027nbog']]

# %%
arima_model = sm.tsa.statespace.SARIMAX(AMT_train,
                                        exog = exog_train2,
                                        order = parameters,
                                        seasonal_order = seasonal_parameters,
                                        enforce_stationarity = False,
                                        enforce_invertability = False,
                                        trend = 't')
results = arima_model.fit()
print(f'Summary: {results.summary()}')
print()
print('Diagnostics: ')
results.plot_diagnostics(figsize = (15,8))
plt.show()
# Out:
# Summary:                                   Statespace Model Results
# ============================================================================================
# Dep. Variable:                                  mid   No. Observations:                  215
# Model:             SARIMAX(11, 1, 2)x(11, 1, 2, 12)   Log Likelihood                -141.356
# Date:                              Tue, 11 Feb 2020   AIC                            354.712
# Time:                                      11:44:20   BIC                            429.503
# Sample:                                  02-01-2000   HQIC                           383.907
#                                        - 12-01-2017
# Covariance Type:                                opg
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# drift              0.0153      0.295      0.052      0.959      -0.562       0.593
# rhedcbw027nbog    -1.7422     11.997     -0.145      0.885     -25.256      21.772
# cildcbw027nbog     0.0555      0.215      0.258      0.797      -0.367       0.478
# usepuindxd        -0.0047      0.020     -0.237      0.812      -0.044       0.034
# clsacbw027nbog    -0.0204      0.045     -0.454      0.650      -0.108       0.068
# vxdcls            -0.6239      0.367     -1.700      0.089      -1.343       0.095
# totci             -0.0522      0.180     -0.291      0.771      -0.404       0.300
# rheacbw027nbog     1.7843     12.118      0.147      0.883     -21.966      25.534
# casdcbw027nbog    -0.0040      0.015     -0.274      0.784      -0.033       0.025
# ar.L1              0.1587     22.061      0.007      0.994     -43.080      43.397
# ar.L2             -0.2430     18.227     -0.013      0.989     -35.968      35.482
# ar.L3             -0.1959     12.593     -0.016      0.988     -24.878      24.486
# ar.L4             -0.1474      5.958     -0.025      0.980     -11.824      11.529
# ar.L5             -0.3164      4.050     -0.078      0.938      -8.254       7.621
# ar.L6             -0.3488      5.932     -0.059      0.953     -11.975      11.277
# ar.L7              0.1549      6.458      0.024      0.981     -12.503      12.812
# ar.L8             -0.0714      6.823     -0.010      0.992     -13.444      13.301
# ar.L9             -0.1400      5.074     -0.028      0.978     -10.085       9.805
# ar.L10            -0.0011      2.102     -0.001      1.000      -4.121       4.119
# ar.L11            -0.0036      1.013     -0.004      0.997      -1.989       1.982
# ma.L1              0.2109     22.178      0.010      0.992     -43.257      43.679
# ma.L2             -0.1269     13.457     -0.009      0.992     -26.503      26.249
# ar.S.L12          -1.1724      0.491     -2.388      0.017      -2.135      -0.210
# ar.S.L24          -1.4892      0.698     -2.132      0.033      -2.858      -0.120
# ar.S.L36          -1.0683      1.125     -0.950      0.342      -3.273       1.137
# ar.S.L48          -1.0434      1.552     -0.672      0.501      -4.085       1.999
# ar.S.L60          -1.2697      1.855     -0.685      0.494      -4.905       2.366
# ar.S.L72          -1.0394      1.893     -0.549      0.583      -4.750       2.671
# ar.S.L84          -0.6977      1.480     -0.471      0.637      -3.599       2.204
# ar.S.L96          -0.4909      1.247     -0.394      0.694      -2.935       1.953
# ar.S.L108         -0.6381      0.937     -0.681      0.496      -2.475       1.199
# ar.S.L120         -0.5398      0.741     -0.728      0.466      -1.993       0.913
# ar.S.L132         -0.4241      0.536     -0.792      0.428      -1.474       0.626
# ma.S.L12           0.3579      0.784      0.457      0.648      -1.178       1.894
# ma.S.L24           0.4827      0.824      0.586      0.558      -1.132       2.097
# sigma2             7.2728      4.279      1.700      0.089      -1.113      15.659
# ===================================================================================
# Ljung-Box (Q):                       35.49   Jarque-Bera (JB):                 0.76
# Prob(Q):                              0.67   Prob(JB):                         0.68
# Heteroskedasticity (H):               1.64   Skew:                            -0.28
# Prob(H) (two-sided):                  0.28   Kurtosis:                         3.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:

# %%
predictions = results.get_prediction(start = pd.to_datetime('2015-01-01'), end = pd.to_datetime('2020-01-01'), dynamic=False, exog = exog_test2)
pred_conf = predictions.conf_int()
    
#Plot observed values
ax = AMT['2000-01-01':].plot(label='observed', figsize = (15,5))

#Plot predicted values
predictions.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9, color = 'darkblue', style = '--')

#Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='lightblue', alpha=.7)

#Set axes labels
ax.set_xlabel('Year')
ax.set_ylabel('Mid Price')
plt.legend(loc = 'best')
plt.title(f'Mid Price Over Time')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Forecasting

# %%
forecast = results.get_forecast(steps = 12, dynamic = False)
pred_conf = forecast.conf_int()

ax = AMT.plot(label = 'observed', figsize = (10,5))
forecast.predicted_mean.plot(ax=ax, label = 'forecast')
ax.fill_between(pred_conf.index, 
                pred_conf.iloc[:,0], 
                pred_conf.iloc[:,1], 
                color = 'k', alpha = .25)

ax.set_xlabel('Year')
ax.set_ylabel('Mid Price')
ax.set_title('AMT Emissions Over Time')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-32e31a3280e8> in <module>
# ----> 1 forecast = results.get_forecast(steps = 12, dynamic = False)
#       2 pred_conf = forecast.conf_int()
#       3
#       4 ax = AMT.plot(label = 'observed', figsize = (10,5))
#       5 forecast.predicted_mean.plot(ax=ax, label = 'forecast')
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/statespace/mlemodel.py in get_forecast(self, steps, **kwargs)
#    2417         else:
#    2418             end = steps
# -> 2419         return self.get_prediction(start=self.nobs, end=end, **kwargs)
#    2420
#    2421     def predict(self, start=None, end=None, dynamic=False, **kwargs):
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/statespace/sarimax.py in get_prediction(self, start, end, dynamic, index, exog, **kwargs)
#    1902             if self.model.k_exog > 0:
#    1903                 if exog is None:
# -> 1904                     raise ValueError('Out-of-sample forecasting in a model'
#    1905                                      ' with a regression component requires'
#    1906                                      ' additional exogenous values via the'
#
# ValueError: Out-of-sample forecasting in a model with a regression component requires additional exogenous values via the `exog` argument.
