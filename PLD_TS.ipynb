# %% [markdown]
# # <center><ins>REIT Time Series Analysis(Ticker: PLD)<ins/><center/>

# %%
from module import decomposition
from module import dickey_fuller
from module import arima_endog
from module import arima_exog
from module import rmse_cv
from module import lasso_reg

import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
from numpy import hstack
import warnings
import os
from fredapi import Fred
warnings.filterwarnings('ignore')

import itertools
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf


# %matplotlib inline
# %load_ext autoreload
# %reload_ext autoreload

# %%
start = datetime(2000,2,1)
end = datetime(2020,1,31)

# %%
PLD = web.DataReader('PLD', 'av-daily', start = start, end = end, api_key = 'Y8YQFOIVHPA381U4')
PLD = PLD.copy()
PLD.to_csv('data/PLD')
PLD.index = pd.to_datetime(PLD.index)
PLD = PLD.resample('MS').mean()
PLD['mid'] = (PLD['high']+PLD['low'])/2
PLD.drop(labels = ['high', 'low', 'open', 'close', 'volume'], axis = 1, inplace = True)

# %%
plt.style.use('ggplot')
PLD.plot(figsize = (16,4))
plt.xlabel('Month')
plt.ylabel('Mid Price')
plt.title('ELS Mid Price Time Series')
plt.tight_layout()
plt.show();

# %% [markdown]
# ## <ins>Time Series Decomposition<ins/>

# %%
decomposition(PLD)

# %%
PLD_diff = PLD.diff(periods = 1).dropna()

# %%
dickey_fuller(PLD_diff)
# Out:
# The series passes the Dickey Fuller Test for Stationarity. P-Value = 2.125252343917822e-22

# %%
plot_pacf(PLD_diff);

# %%
plot_acf(PLD_diff);

# %%
parameters = (2,1,5)
seasonal_parameters = (2,1,5,12)

# %%
PLD_train = PLD[:'2017']
PLD_test = PLD['2018':]

# %% [markdown]
# ## <ins>SARIMAX Model w/o Exogenous Variables<ins/>

# %%
arima_endog(PLD_train, PLD, parameters, seasonal_parameters)
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  215
# Model:             SARIMAX(2, 1, 5)x(2, 1, 5, 12)   Log Likelihood                -335.694
# Date:                            Thu, 13 Feb 2020   AIC                            703.387
# Time:                                    11:16:54   BIC                            749.990
# Sample:                                02-01-2000   HQIC                           722.326
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift          0.0008      0.004      0.185      0.853      -0.007       0.009
# ar.L1         -0.3502      0.177     -1.978      0.048      -0.697      -0.003
# ar.L2         -0.7072      0.155     -4.563      0.000      -1.011      -0.403
# ma.L1          0.5614      0.206      2.726      0.006       0.158       0.965
# ma.L2          0.7757      0.210      3.702      0.000       0.365       1.186
# ma.L3          0.2485      0.130      1.908      0.056      -0.007       0.504
# ma.L4          0.1708      0.095      1.792      0.073      -0.016       0.357
# ma.L5          0.3133      0.086      3.641      0.000       0.145       0.482
# ar.S.L12      -1.0460      0.149     -7.035      0.000      -1.337      -0.755
# ar.S.L24      -0.7398      0.120     -6.182      0.000      -0.974      -0.505
# ma.S.L12       0.1378      3.124      0.044      0.965      -5.985       6.261
# ma.S.L24      -0.2955      3.572     -0.083      0.934      -7.296       6.705
# ma.S.L36      -0.8638      2.610     -0.331      0.741      -5.979       4.252
# ma.S.L48      -0.0189      0.128     -0.147      0.883      -0.270       0.232
# ma.S.L60       0.0587      0.188      0.312      0.755      -0.310       0.428
# sigma2         6.2170     19.049      0.326      0.744     -31.118      43.552
# ===================================================================================
# Ljung-Box (Q):                       22.28   Jarque-Bera (JB):               159.76
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.25   Skew:                            -1.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Predictions vs. Observed:

# %% [markdown]
# ## <ins>Determine Exogenous Feature Importance<ins/>

# %%
PLD_rates = pd.read_csv('data/PLD_rates.csv', index_col = 'date')

# %%
lasso_reg(PLD_rates)
# Out:
# The R-score of the Lasso Regression is: 0.9840421603036983

# %%
PLD_rates_train = PLD_rates[:'2018']
PLD_rates_test = PLD_rates['2018':]

# %%
exog_train = PLD_rates_train[['cildcbw027nbog', 'relacbw027nbog', 'totci', 'casdcbw027nbog', 'rheacbw027nbog']]

# %%
exog_test = PLD_rates_test[['cildcbw027nbog', 'relacbw027nbog', 'totci', 'casdcbw027nbog', 'rheacbw027nbog']]

# %% [markdown]
# ## <ins> SARIMAX Model w/ Exogenous Variables<ins/>

# %%
arima_exog(PLD_train, PLD, parameters, seasonal_parameters, exog_train, exog_test)
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  215
# Model:             SARIMAX(2, 1, 5)x(2, 1, 5, 12)   Log Likelihood                -322.484
# Date:                            Thu, 13 Feb 2020   AIC                            686.967
# Time:                                    11:18:24   BIC                            748.133
# Sample:                                02-01-2000   HQIC                           711.824
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# drift             -0.0050      0.002     -2.218      0.027      -0.009      -0.001
# cildcbw027nbog    -0.0459      0.086     -0.535      0.593      -0.214       0.122
# relacbw027nbog     0.0501      0.017      2.977      0.003       0.017       0.083
# totci             -0.0033      0.067     -0.049      0.961      -0.134       0.128
# casdcbw027nbog     0.0011      0.007      0.168      0.867      -0.012       0.014
# rheacbw027nbog    -0.4396      0.080     -5.511      0.000      -0.596      -0.283
# ar.L1              0.5118      0.018     28.907      0.000       0.477       0.546
# ar.L2             -0.9881      0.016    -60.581      0.000      -1.020      -0.956
# ma.L1             -0.3253      0.099     -3.273      0.001      -0.520      -0.131
# ma.L2              0.8927      0.195      4.568      0.000       0.510       1.276
# ma.L3              0.2429      0.126      1.923      0.054      -0.005       0.490
# ma.L4             -0.0093      0.116     -0.080      0.936      -0.237       0.218
# ma.L5              0.0494      0.099      0.497      0.619      -0.145       0.244
# ar.S.L12          -0.7341      0.321     -2.285      0.022      -1.364      -0.104
# ar.S.L24          -0.4373      0.244     -1.793      0.073      -0.915       0.041
# ma.S.L12           0.0459      0.449      0.102      0.919      -0.834       0.926
# ma.S.L24          -0.4547      0.305     -1.491      0.136      -1.053       0.143
# ma.S.L36          -0.3290      0.319     -1.032      0.302      -0.954       0.296
# ma.S.L48          -0.0715      0.182     -0.394      0.694      -0.428       0.285
# ma.S.L60          -0.0378      0.188     -0.201      0.841      -0.406       0.331
# sigma2             5.8425      1.709      3.419      0.001       2.493       9.192
# ===================================================================================
# Ljung-Box (Q):                       35.69   Jarque-Bera (JB):                 1.17
# Prob(Q):                              0.66   Prob(JB):                         0.56
# Heteroskedasticity (H):               0.35   Skew:                            -0.17
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Predictions vs. Observed:
