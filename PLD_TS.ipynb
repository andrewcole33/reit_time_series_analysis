# %%
from module import decomposition
from module import dickey_fuller
from module import arima_endog
from module import arima_exog
from module import rmse_cv
from module import lasso_reg


import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from numpy import hstack
import warnings
import os
from fredapi import Fred
warnings.filterwarnings('ignore')

import itertools
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from sklearn.metrics import mean_squared_error
import pmdarima as pm
from pmdarima import model_selection

from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# %matplotlib inline
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Set Datetime

# %%
start = datetime(2000,2,1)
end = datetime(2020,1,31)

# %% [markdown]
# ## Gather Endogenous Data

# %%
PLD = web.DataReader('PLD', 'av-daily', start = start, end = end, api_key = 'Y8YQFOIVHPA381U4')
PLD = PLD.copy()
PLD.index = pd.to_datetime(PLD.index)
PLD = PLD.resample('MS').mean()
PLD['mid'] = (PLD['high']+PLD['low'])/2
PLD.drop(labels = ['high', 'low', 'open', 'close', 'volume'], axis = 1, inplace = True)

# %%
plt.style.use('ggplot')
PLD.plot(figsize = (16,4))
plt.xlabel('Month')
plt.ylabel('Mid Price')
plt.title('ELS Mid Price Time Series')
plt.tight_layout()
plt.show();

# %% [markdown]
# ## Perform Decomposition of Time Series

# %%
decomposition(PLD)

# %%
PLD_diff = PLD.diff(periods = 1).dropna()

# %%
dickey_fuller(PLD_diff)
# Out:
# The series passes the Dickey Fuller Test for Stationarity. P-Value = 2.124127317398241e-22

# %%
plot_pacf(PLD_diff);

# %%
plot_acf(PLD_diff);

# %%
parameters = (2,1,5)
seasonal_parameters = (2,1,5,12)

# %% [markdown]
# ## Train Test Split

# %%
PLD_train = PLD[:'2017']
PLD_test = PLD['2018':]

# %% [markdown]
# ## SARIMAX Model (No Exogenous Variables)

# %%
arima_endog(PLD_train, PLD, parameters, seasonal_parameters)
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  215
# Model:             SARIMAX(2, 1, 5)x(2, 1, 5, 12)   Log Likelihood                -336.979
# Date:                            Mon, 10 Feb 2020   AIC                            705.958
# Time:                                    14:46:59   BIC                            752.561
# Sample:                                02-01-2000   HQIC                           724.896
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift          0.0012      0.004      0.318      0.751      -0.006       0.009
# ar.L1         -0.3336      0.221     -1.511      0.131      -0.766       0.099
# ar.L2         -0.7223      0.178     -4.057      0.000      -1.071      -0.373
# ma.L1          0.5615      0.244      2.301      0.021       0.083       1.040
# ma.L2          0.7584      0.244      3.103      0.002       0.279       1.237
# ma.L3          0.2247      0.135      1.659      0.097      -0.041       0.490
# ma.L4          0.1153      0.099      1.168      0.243      -0.078       0.309
# ma.L5          0.2426      0.089      2.721      0.007       0.068       0.417
# ar.S.L12      -1.0524      0.168     -6.278      0.000      -1.381      -0.724
# ar.S.L24      -0.7245      0.132     -5.470      0.000      -0.984      -0.465
# ma.S.L12       0.1209      1.556      0.078      0.938      -2.928       3.170
# ma.S.L24      -0.3578      1.726     -0.207      0.836      -3.741       3.026
# ma.S.L36      -0.7546      1.206     -0.626      0.531      -3.118       1.609
# ma.S.L48       0.0332      0.130      0.254      0.799      -0.222       0.289
# ma.S.L60      -0.0078      0.206     -0.038      0.970      -0.412       0.397
# sigma2         6.3094      9.647      0.654      0.513     -12.599      25.218
# ===================================================================================
# Ljung-Box (Q):                       21.27   Jarque-Bera (JB):               190.27
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.26   Skew:                            -1.17
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Predictions vs. Observed:

# %%
mse = mean_squared_error(PLD_test, predictions.predicted_mean['2018':])
mse
# Out:
# 204.24890731460545

# %% [markdown]
# ## Gather Exogenous Variables

# %%
PLD_rates = pd.read_csv('data/PLD_rates.csv', index_col = 'date')

# %% [markdown]
# ### Train Test Split Exogenous Variables

# %% [markdown]
# ### Perform Lasso Regression

# %%
lasso_reg(PLD_rates)
# Out:
# The R-score of the Lasso Regression is: 0.9840421603036983
#
# usd1mtd156n       0.000000
# mortgage30us     -0.000000
# mortgage15us     -0.000000
# dcpf3m            0.000000
# cpn3m             0.000000
# dcpf1m            0.000000
# aaa              -0.000000
# baa              -0.000000
# dff               0.000000
# flexsc            0.000000
# t10y2y           -0.000000
# t10y3m           -0.000000
# tedrate           0.000000
# t10yff           -0.000000
# t5yff            -0.000000
# tb6smffm         -0.000000
# usd3mtd156n       0.000000
# usd12md156n       0.000000
# eur1wkd156n       0.000000
# mprime            0.000000
# tb3ms             0.000000
# dtb6              0.000000
# dgs10            -0.000000
# dgs3mo            0.000000
# dexuseu           0.000000
# dexchus          -0.000000
# dexusuk           0.000000
# dexsius          -0.000000
# nasdaqcom        -0.003729
# willreitind       0.005984
# willlrgcap        0.000931
# willsmlcap        0.000033
# vxdcls           -0.000000
# stlfsi            0.000000
# nfci              0.000000
# h8b3094ncba       0.000008
# bc0dcbw027nbog   -0.011700
# casdcbw027nbog   -0.022888
# cildcbw027nbog    0.020500
# dpsdcbw027nbog    0.000785
# rhedcbw027nbog   -0.000000
# clsacbw027nbog   -0.009378
# dpsacbw027nbog    0.004626
# relacbw027nbog    0.016894
# rheacbw027nbog   -0.021973
# tlaacbw027nbog   -0.001596
# tlbacbw027nbog    0.001007
# totci            -0.026952
# usepuindxd       -0.003832
# wlemuindxd        0.006218
# emvfincrises     -0.000000
# stlppm            0.000000
# dtype: float64
#
# Lasso picked 18 variables and eliminated the other 34 variables

# %% [markdown]
# ### Select significant exogenous features from Lasso Regression

# %%
PLD_rates_train = PLD_rates[:'2018']
PLD_rates_test = PLD_rates['2018':]

# %%
exog_train = PLD_rates_train[['cildcbw027nbog', 'relacbw027nbog', 'totci', 'casdcbw027nbog', 'rheacbw027nbog']]

# %%
exog_test = PLD_rates_test[['cildcbw027nbog', 'relacbw027nbog', 'totci', 'casdcbw027nbog', 'rheacbw027nbog']]

# %%
exog_train.shape, exog_test.shape
# Out:
# ((215, 5), (25, 5))

# %%
arima_model = sm.tsa.statespace.SARIMAX(PLD_train,
                                        exog = exog_train,
                                        order = parameters,
                                        seasonal_order = seasonal_parameters,
                                        enforce_stationarity = False,
                                        enforce_invertability = False,
                                        trend = 't')
results = arima_model.fit()
print(f'Summary: {results.summary()}')
print()
print('Diagnostics: ')
results.plot_diagnostics(figsize = (15,8))
plt.show()
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  215
# Model:             SARIMAX(2, 1, 5)x(2, 1, 5, 12)   Log Likelihood                -321.706
# Date:                            Mon, 10 Feb 2020   AIC                            685.411
# Time:                                    14:51:17   BIC                            746.577
# Sample:                                02-01-2000   HQIC                           710.268
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# drift             -0.0055      0.003     -2.185      0.029      -0.010      -0.001
# cildcbw027nbog    -0.1004      0.087     -1.160      0.246      -0.270       0.069
# relacbw027nbog     0.0486      0.017      2.932      0.003       0.016       0.081
# totci              0.0451      0.069      0.652      0.515      -0.091       0.181
# casdcbw027nbog     0.0025      0.007      0.384      0.701      -0.010       0.015
# rheacbw027nbog    -0.4553      0.082     -5.561      0.000      -0.616      -0.295
# ar.L1              0.5152      0.014     36.266      0.000       0.487       0.543
# ar.L2             -0.9914      0.013    -73.746      0.000      -1.018      -0.965
# ma.L1             -0.3329      0.095     -3.492      0.000      -0.520      -0.146
# ma.L2              0.9151      0.162      5.635      0.000       0.597       1.233
# ma.L3              0.2837      0.125      2.274      0.023       0.039       0.528
# ma.L4             -0.0237      0.117     -0.202      0.840      -0.254       0.207
# ma.L5              0.1093      0.106      1.032      0.302      -0.098       0.317
# ar.S.L12          -0.8129      0.232     -3.504      0.000      -1.268      -0.358
# ar.S.L24          -0.5226      0.193     -2.712      0.007      -0.900      -0.145
# ma.S.L12           0.1514      0.423      0.358      0.720      -0.677       0.980
# ma.S.L24          -0.3807      0.381     -1.000      0.317      -1.127       0.365
# ma.S.L36          -0.4738      0.299     -1.585      0.113      -1.060       0.112
# ma.S.L48          -0.1485      0.185     -0.804      0.421      -0.511       0.214
# ma.S.L60          -0.0087      0.188     -0.046      0.963      -0.378       0.360
# sigma2             5.8557      1.793      3.265      0.001       2.340       9.371
# ===================================================================================
# Ljung-Box (Q):                       33.23   Jarque-Bera (JB):                 0.94
# Prob(Q):                              0.77   Prob(JB):                         0.63
# Heteroskedasticity (H):               0.35   Skew:                            -0.14
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:

# %%
predictions = results.get_prediction(start = pd.to_datetime('2015-01-01'), end = pd.to_datetime('2020-01-01'), dynamic=False, exog = exog_test)
pred_conf = predictions.conf_int()
    
#Plot observed values
ax = PLD['2011-02-01':].plot(label='observed', figsize = (15,5))

#Plot predicted values
predictions.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9, color = 'darkblue', style = '--')

#Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='lightblue', alpha=.7)

#Set axes labels
ax.set_xlabel('Year')
ax.set_ylabel('Mid Price')
plt.legend(loc = 'best')
plt.title(f'Mid Price Over Time')
plt.tight_layout()
plt.show()
