# %%
from module import decomposition
from module import dickey_fuller
from module import arima_endog
from module import arima_exog
from module import rmse_cv
from module import lasso_reg


import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from numpy import hstack
import warnings
import os
from fredapi import Fred
warnings.filterwarnings('ignore')

import itertools
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
import pmdarima as pm
from pmdarima import model_selection

from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# %matplotlib inline
# %load_ext autoreload
# %autoreload
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Set Datetime

# %%
start = datetime(2000,2,1)
end = datetime(2020,1,31)

# %% [markdown]
# ## Gather Endogenous Data

# %%
ELS = web.DataReader('ELS', 'av-daily', start = start, end = end, api_key = 'Y8YQFOIVHPA381U4')
ELS = ELS.copy()
ELS.index = pd.to_datetime(ELS.index)
ELS = ELS.resample('MS').mean()
ELS['mid'] = (ELS['high']+ELS['low'])/2
ELS.drop(labels = ['high', 'low', 'open', 'close', 'volume'], axis = 1, inplace = True)

# %%
plt.style.use('ggplot')
ELS.plot(figsize = (16,4))
plt.xlabel('Month')
plt.ylabel('Mid Price')
plt.title('ELS Mid Price Time Series')
plt.tight_layout()
plt.show();

# %% [markdown]
# ## Perform Decomposition of Time Series

# %%
decomposition(ELS)

# %%
ELS_diff = ELS.diff(periods = 1).dropna()

# %%
dickey_fuller(ELS_diff)
# Out:
# The series passes the Dickey Fuller Test for Stationarity. P-Value = 3.364492668109627e-19

# %%
plot_pacf(ELS_diff);

# %%
plot_acf(ELS_diff);

# %%
parameters = (2,1,1)
seasonal_parameters = (2,1,1,12)

# %% [markdown]
# ## Train Test Split

# %%
ELS_train = ELS[:'2015']
ELS_test = ELS['2016':]

# %% [markdown]
# ## SARIMAX Model (No Exogenous Variables)

# %%
arima_endog(ELS_train, parameters, seasonal_parameters)
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  191
# Model:             SARIMAX(2, 1, 1)x(2, 1, 1, 12)   Log Likelihood                -398.527
# Date:                            Sun, 09 Feb 2020   AIC                            813.055
# Time:                                    23:00:40   BIC                            837.246
# Sample:                                02-01-2000   HQIC                           822.882
#                                      - 12-01-2015
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift      -4.105e-05      0.001     -0.065      0.948      -0.001       0.001
# ar.L1          0.5572      0.731      0.762      0.446      -0.876       1.990
# ar.L2         -0.1973      0.278     -0.709      0.478      -0.743       0.348
# ma.L1         -0.1731      0.753     -0.230      0.818      -1.649       1.302
# ar.S.L12      -0.0904      0.126     -0.719      0.472      -0.337       0.156
# ar.S.L24      -0.1965      0.127     -1.545      0.122      -0.446       0.053
# ma.S.L12      -0.8452      0.154     -5.486      0.000      -1.147      -0.543
# sigma2         9.9019      1.075      9.213      0.000       7.795      12.008
# ===================================================================================
# Ljung-Box (Q):                       24.74   Jarque-Bera (JB):               526.74
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.11   Skew:                            -1.90
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Predictions vs. Observed:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Future Forecast:

# %% [markdown]
# ## Gather Exogenous Variables

# %%
ELS_rates = pd.read_csv('data/ELS_rates.csv', index_col = 'date')

# %% [markdown]
# ### Train Test Split Exogenous Variables

# %% [markdown]
# ### Perform Lasso Regression

# %%
lasso_reg(ELS_rates)
# Out:
# The R-score of the Lasso Regression is: 0.8939007612743599
#
# usd1mtd156n      -0.000000
# mortgage30us     -0.000000
# mortgage15us     -0.000000
# dcpf3m           -0.000000
# cpn3m            -0.000000
# dcpf1m           -0.000000
# aaa              -0.000000
# baa              -0.000000
# dff              -0.000000
# flexsc           -0.000000
# t10y2y           -0.000000
# t10y3m           -0.000000
# tedrate          -0.000000
# t10yff           -0.000000
# t5yff            -0.000000
# tb6smffm         -0.000000
# usd3mtd156n      -0.000000
# usd12md156n      -0.000000
# eur1wkd156n      -0.000000
# mprime           -0.000000
# tb3ms            -0.000000
# dtb6             -0.000000
# dgs10            -0.000000
# dgs3mo           -0.000000
# dexuseu           0.000000
# dexchus          -0.000000
# dexusuk          -0.000000
# dexsius          -0.000000
# nasdaqcom         0.005112
# willreitind       0.004831
# willlrgcap       -0.001561
# willsmlcap        0.000154
# vxdcls            0.095614
# stlfsi           -0.000000
# nfci              0.000000
# h8b3094ncba      -0.000028
# bc0dcbw027nbog    0.016392
# casdcbw027nbog   -0.012646
# cildcbw027nbog   -0.016684
# dpsdcbw027nbog    0.008969
# rhedcbw027nbog   -0.000000
# clsacbw027nbog    0.040936
# dpsacbw027nbog   -0.007005
# relacbw027nbog    0.027800
# rheacbw027nbog   -0.052777
# tlaacbw027nbog   -0.007433
# tlbacbw027nbog   -0.006824
# totci             0.033358
# usepuindxd        0.024110
# wlemuindxd       -0.020843
# emvfincrises      0.000000
# stlppm           -0.000000
# dtype: float64
#
# Lasso picked 19 variables and eliminated the other 33 variables

# %% [markdown]
# ### Select significant exogenous features from Lasso Regression

# %%
ELS_rates_train = ELS_rates[:'2016']
ELS_rates_test = ELS_rates['2016':]

# %%
exog_train = ELS_rates_train[['nasdaqcom', 'willreitind', 'willlrgcap', 'willsmlcap', 'vxdcls', 'h8b3094ncba', 'bc0dcbw027nbog', 'bc0dcbw027nbog', 'casdcbw027nbog', 'cildcbw027nbog',
                             'dpsdcbw027nbog', 'clsacbw027nbog', 'dpsacbw027nbog', 'relacbw027nbog', 'rheacbw027nbog', 'tlaacbw027nbog', 'tlbacbw027nbog', 'totci', 
                              'usepuindxd','wlemuindxd']]

# %%
exog_test = ELS_rates_test[['nasdaqcom', 'willreitind', 'willlrgcap', 'willsmlcap', 'vxdcls', 'h8b3094ncba', 'bc0dcbw027nbog', 'bc0dcbw027nbog', 'casdcbw027nbog', 'cildcbw027nbog',
                             'dpsdcbw027nbog', 'clsacbw027nbog', 'dpsacbw027nbog', 'relacbw027nbog', 'rheacbw027nbog', 'tlaacbw027nbog', 'tlbacbw027nbog', 'totci', 
                              'usepuindxd','wlemuindxd']]

# %%
exog_train.shape, exog_test.shape
# Out:
# ((191, 20), (49, 20))

# %%
arima_model = sm.tsa.statespace.SARIMAX(ELS_train,
                                        exog = exog_train,
                                        order = parameters,
                                        seasonal_order = seasonal_parameters,
                                        enforce_stationarity = False,
                                        enforce_invertability = False,
                                        trend = 't')
results = arima_model.fit()
print(f'Summary: {results.summary()}')
print()
print('Diagnostics: ')
results.plot_diagnostics(figsize = (15,8))
plt.show()
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  191
# Model:             SARIMAX(2, 1, 1)x(2, 1, 1, 12)   Log Likelihood                -356.591
# Date:                            Sun, 09 Feb 2020   AIC                            769.182
# Time:                                    23:00:48   BIC                            853.851
# Sample:                                02-01-2000   HQIC                           803.578
#                                      - 12-01-2015
# Covariance Type:                              opg
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# drift              0.0003      0.003      0.089      0.929      -0.006       0.007
# nasdaqcom          0.0018      0.012      0.159      0.874      -0.021       0.025
# willreitind        0.0102      0.002      4.709      0.000       0.006       0.014
# willlrgcap         0.0006      0.001      0.469      0.639      -0.002       0.003
# willsmlcap        -0.0008      0.001     -1.408      0.159      -0.002       0.000
# vxdcls             0.0313      0.193      0.163      0.871      -0.346       0.409
# h8b3094ncba     7.563e-07   1.78e-05      0.043      0.966   -3.41e-05    3.56e-05
# bc0dcbw027nbog     0.0116      0.011      1.053      0.293      -0.010       0.033
# bc0dcbw027nbog     0.0116      0.011      1.053      0.293      -0.010       0.033
# casdcbw027nbog     0.0077      0.016      0.466      0.641      -0.025       0.040
# cildcbw027nbog    -0.0303      0.129     -0.235      0.814      -0.283       0.222
# dpsdcbw027nbog    -0.0071      0.021     -0.336      0.737      -0.048       0.034
# clsacbw027nbog    -0.0204      0.033     -0.615      0.539      -0.086       0.045
# dpsacbw027nbog    -0.0058      0.019     -0.302      0.763      -0.043       0.032
# relacbw027nbog    -0.0119      0.028     -0.434      0.664      -0.066       0.042
# rheacbw027nbog    -0.0829      0.146     -0.568      0.570      -0.369       0.203
# tlaacbw027nbog     0.0175      0.029      0.601      0.548      -0.040       0.075
# tlbacbw027nbog    -0.0185      0.031     -0.599      0.549      -0.079       0.042
# totci              0.0045      0.096      0.047      0.962      -0.184       0.194
# usepuindxd        -0.0029      0.015     -0.190      0.849      -0.033       0.027
# wlemuindxd        -0.0023      0.010     -0.241      0.810      -0.021       0.016
# ar.L1              0.4064      0.603      0.674      0.501      -0.776       1.589
# ar.L2             -0.1828      0.301     -0.607      0.544      -0.773       0.408
# ma.L1              0.1473      0.643      0.229      0.819      -1.114       1.408
# ar.S.L12          -0.6018      0.440     -1.368      0.171      -1.464       0.261
# ar.S.L24          -0.5585      0.328     -1.700      0.089      -1.202       0.085
# ma.S.L12          -0.2282      0.421     -0.542      0.588      -1.053       0.597
# sigma2             8.3675      1.393      6.006      0.000       5.637      11.098
# ===================================================================================
# Ljung-Box (Q):                       37.51   Jarque-Bera (JB):              1797.51
# Prob(Q):                              0.58   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.60   Skew:                            -2.50
# Prob(H) (two-sided):                  0.00   Kurtosis:                        19.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.95e+19. Standard errors may be unstable.
#
# Diagnostics:

# %%
predictions = results.get_prediction(start = pd.to_datetime('2015-01-01'), end = pd.to_datetime('2020-01-01'), dynamic=True, exog = exog_test)
pred_conf = predictions.conf_int()
    
#Plot observed values
ax = ELS['2011-02-01':].plot(label='observed', figsize = (10,5))

#Plot predicted values
predictions.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9, color = 'darkblue')

#Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='lightblue', alpha=.7)

#Set axes labels
ax.set_xlabel('Year')
ax.set_ylabel('Mid Price')
plt.legend(loc = 'best')
plt.title(f'Mid Price Over Time')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Auto ARIMA

# %%
ts = ELS
full_exog = exog_train.append(exog_test)
auto_arima = auto_arima = pm.auto_arima(ts, 
                      exogenous = full_exog,
                      error_action='ignore', trace=True,
                      suppress_warnings=True, d =1,
                      seasonal=True, m=12,
                      start_p=0, start_q=0,
                      start_P=0, start_Q=0,
                      stationary=False,
                      with_intercept=False, 
                      D = 12, trend = 't')
# Out:
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 12, 0, 12); AIC=2434.473, BIC=2490.659, Fit time=422.740 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 12, 0, 12); AIC=2441.435, BIC=2502.728, Fit time=307.024 seconds
# Near non-invertible roots for order (1, 1, 0)(1, 12, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 12, 1, 12); AIC=2453.004, BIC=2514.297, Fit time=384.914 seconds
# Near non-invertible roots for order (0, 1, 1)(0, 12, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.992)
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 12, 0, 12); AIC=2452.711, BIC=2511.450, Fit time=462.077 seconds
# Near non-invertible roots for order (0, 1, 0)(1, 12, 0, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 12, 1, 12); AIC=2465.240, BIC=2523.979, Fit time=158.947 seconds
# Near non-invertible roots for order (0, 1, 0)(0, 12, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.991)
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(1, 12, 1, 12); AIC=2434.207, BIC=2495.500, Fit time=347.903 seconds
# Near non-invertible roots for order (0, 1, 0)(1, 12, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 12, 0, 12); AIC=2470.463, BIC=2529.202, Fit time=305.547 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 12, 0, 12); AIC=2474.492, BIC=2533.232, Fit time=300.679 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 12, 0, 12); AIC=2473.251, BIC=2534.544, Fit time=336.918 seconds
# Total fit time: 3026.763 seconds
