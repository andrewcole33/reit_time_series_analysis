# %% [markdown]
# # <center><ins>REIT Time Series Analysis(Ticker: ELS)<ins/><center/>

# %%
from module import decomposition
from module import dickey_fuller
from module import arima_endog
from module import arima_exog
from module import rmse_cv
from module import lasso_reg

import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np
from numpy import hstack
import warnings
import os
from fredapi import Fred
warnings.filterwarnings('ignore')

import itertools
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf


# %matplotlib inline
# %load_ext autoreload
# %reload_ext autoreload

# %%
start = datetime(2000,2,1)
end = datetime(2020,1,31)

# %%
ELS = web.DataReader('ELS', 'av-daily', start = start, end = end, api_key = 'Y8YQFOIVHPA381U4')
ELS = ELS.copy()
ELS.to_csv('data/ELS_GRU.csv')
ELS.index = pd.to_datetime(ELS.index)
ELS = ELS.resample('MS').mean()
ELS['mid'] = (ELS['high']+ELS['low'])/2
ELS.drop(labels = ['high', 'low', 'open', 'close', 'volume'], axis = 1, inplace = True)

# %%
plt.style.use('ggplot')
ELS.plot(figsize = (16,4))
plt.xlabel('Month')
plt.ylabel('Mid Price')
plt.title('ELS Mid Price Time Series')
plt.tight_layout()
plt.show();

# %% [markdown]
# ## <ins>Time Series Decomposition<ins/>

# %%
decomposition(ELS)

# %%
ELS_diff = ELS.diff(periods = 1).dropna()

# %%
dickey_fuller(ELS_diff)
# Out:
# The series passes the Dickey Fuller Test for Stationarity. P-Value = 3.3643127278010166e-19

# %%
plot_pacf(ELS_diff);

# %%
plot_acf(ELS_diff);

# %%
parameters = (2,1,4)
seasonal_parameters = (2,1,4,12)

# %%
ELS_train = ELS[:'2017']
ELS_test = ELS['2018':]

# %% [markdown]
# ## <ins>SARIMAX Model w/o Exogenous<ins/>

# %%
arima_endog(ELS_train, ELS, parameters, seasonal_parameters)
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  215
# Model:             SARIMAX(2, 1, 4)x(2, 1, 4, 12)   Log Likelihood                -388.785
# Date:                            Wed, 12 Feb 2020   AIC                            805.571
# Time:                                    10:56:32   BIC                            847.626
# Sample:                                02-01-2000   HQIC                           822.657
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift          0.0010      0.002      0.562      0.574      -0.002       0.004
# ar.L1         -0.0642      0.698     -0.092      0.927      -1.433       1.304
# ar.L2         -0.1056      0.485     -0.218      0.828      -1.057       0.845
# ma.L1          0.5206      0.710      0.734      0.463      -0.870       1.911
# ma.L2          0.2476      0.324      0.765      0.445      -0.387       0.882
# ma.L3         -0.2653      0.176     -1.506      0.132      -0.611       0.080
# ma.L4         -0.1760      0.317     -0.556      0.579      -0.797       0.445
# ar.S.L12      -1.0200      0.289     -3.528      0.000      -1.587      -0.453
# ar.S.L24      -0.7275      0.199     -3.653      0.000      -1.118      -0.337
# ma.S.L12       0.0395      0.759      0.052      0.959      -1.449       1.528
# ma.S.L24      -0.3167      0.744     -0.426      0.670      -1.775       1.141
# ma.S.L36      -0.6428      0.534     -1.203      0.229      -1.690       0.405
# ma.S.L48      -0.0290      0.154     -0.188      0.851      -0.332       0.274
# sigma2         9.6253      6.188      1.556      0.120      -2.502      21.753
# ===================================================================================
# Ljung-Box (Q):                       31.77   Jarque-Bera (JB):               165.28
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                            -1.25
# Prob(H) (two-sided):                  0.41   Kurtosis:                         7.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Predictions vs. Observed:

# %% [markdown]
# ## <ins>Determine Exogenous Feature Importance<ins/>

# %%
ELS_rates = pd.read_csv('data/ELS_rates.csv', index_col = 'date')

# %%
lasso_reg(ELS_rates)
# Out:
# The R-score of the Lasso Regression is: 0.8939007612743599

# %%
ELS_rates_train = ELS_rates[:'2018']
ELS_rates_test = ELS_rates['2018':]

# %%
exog_train = ELS_rates_train[['vxdcls', 'clsacbw027nbog', 'totci', 'relacbw027nbog', 'usepuindxd', 'bc0dcbw027nbog', 'rheacbw027nbog']]

# %%
exog_test = ELS_rates_test[['vxdcls', 'clsacbw027nbog', 'totci', 'relacbw027nbog', 'usepuindxd', 'bc0dcbw027nbog', 'rheacbw027nbog']]

# %% [markdown]
# ## <ins>SARIMAX Model w/ Exogenous Variables<ins/>

# %%
arima_exog(ELS_train, ELS, parameters, seasonal_parameters, exog_train, exog_test)
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  215
# Model:             SARIMAX(2, 1, 4)x(2, 1, 4, 12)   Log Likelihood                -382.754
# Date:                            Wed, 12 Feb 2020   AIC                            807.508
# Time:                                    10:57:19   BIC                            870.591
# Sample:                                02-01-2000   HQIC                           833.137
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# drift             -0.0007      0.001     -0.526      0.599      -0.003       0.002
# vxdcls            -0.2799      0.177     -1.578      0.115      -0.628       0.068
# clsacbw027nbog    -0.0122      0.042     -0.294      0.769      -0.094       0.069
# totci             -0.0324      0.057     -0.574      0.566      -0.143       0.078
# relacbw027nbog     0.0121      0.037      0.322      0.748      -0.061       0.086
# usepuindxd        -0.0134      0.017     -0.795      0.427      -0.047       0.020
# bc0dcbw027nbog     0.0215      0.027      0.794      0.427      -0.032       0.074
# rheacbw027nbog    -0.1983      0.161     -1.234      0.217      -0.513       0.117
# ar.L1              0.1385      1.297      0.107      0.915      -2.403       2.680
# ar.L2              0.4128      1.199      0.344      0.731      -1.937       2.763
# ma.L1              0.4306      1.295      0.332      0.740      -2.108       2.969
# ma.L2             -0.3837      0.643     -0.596      0.551      -1.645       0.877
# ma.L3             -0.3873      0.578     -0.670      0.503      -1.519       0.745
# ma.L4             -0.1838      0.308     -0.597      0.550      -0.787       0.419
# ar.S.L12          -0.6748      0.230     -2.938      0.003      -1.125      -0.225
# ar.S.L24          -0.7566      0.254     -2.983      0.003      -1.254      -0.259
# ma.S.L12          -0.2329      0.324     -0.719      0.472      -0.868       0.402
# ma.S.L24           0.3101      0.392      0.792      0.428      -0.457       1.078
# ma.S.L36          -0.6518      0.374     -1.745      0.081      -1.384       0.080
# ma.S.L48          -0.0873      0.191     -0.456      0.648      -0.462       0.288
# sigma2            12.0720      3.122      3.866      0.000       5.952      18.192
# ===================================================================================
# Ljung-Box (Q):                       43.00   Jarque-Bera (JB):               335.71
# Prob(Q):                              0.34   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.49   Skew:                            -1.51
# Prob(H) (two-sided):                  0.16   Kurtosis:                         9.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Predictions vs. Observed:
