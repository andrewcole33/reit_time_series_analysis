# %%
from module import decomposition
from module import dickey_fuller
from module import arima_endog
from module import arima_exog
from module import rmse_cv
from module import lasso_reg


import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from numpy import hstack
import warnings
import os
from fredapi import Fred
warnings.filterwarnings('ignore')

import itertools
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
import pmdarima as pm
from pmdarima import model_selection

from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# %matplotlib inline
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Set Datetime

# %%
start = datetime(2000,2,1)
end = datetime(2020,1,31)

# %% [markdown]
# ## Gather Endogenous Data

# %%
ELS = web.DataReader('ELS', 'av-daily', start = start, end = end, api_key = 'Y8YQFOIVHPA381U4')
ELS = ELS.copy()
ELS.index = pd.to_datetime(ELS.index)
ELS = ELS.resample('MS').mean()
ELS['mid'] = (ELS['high']+ELS['low'])/2
ELS.drop(labels = ['high', 'low', 'open', 'close', 'volume'], axis = 1, inplace = True)

# %%
plt.style.use('ggplot')
ELS.plot(figsize = (16,4))
plt.xlabel('Month')
plt.ylabel('Mid Price')
plt.title('ELS Mid Price Time Series')
plt.tight_layout()
plt.show();

# %% [markdown]
# ## Perform Decomposition of Time Series

# %%
decomposition(ELS)

# %%
ELS_diff = ELS.diff(periods = 1).dropna()

# %%
dickey_fuller(ELS_diff)
# Out:
# The series passes the Dickey Fuller Test for Stationarity. P-Value = 3.364492668109627e-19

# %%
plot_pacf(ELS_diff);

# %%
plot_acf(ELS_diff);

# %% [markdown]
# ## Train Test Split

# %%
ELS_train = ELS[:'2017']
ELS_test = ELS['2018':]

# %% [markdown]
# ## SARIMAX Model (No Exogenous Variables)

# %%
arima_endog(ELS_train, ELS, (2,1,4), (2,1,4,12))
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  215
# Model:             SARIMAX(2, 1, 4)x(2, 1, 4, 12)   Log Likelihood                -388.450
# Date:                            Mon, 10 Feb 2020   AIC                            804.900
# Time:                                    15:33:33   BIC                            846.955
# Sample:                                02-01-2000   HQIC                           821.986
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift          0.0010      0.002      0.506      0.613      -0.003       0.005
# ar.L1         -0.0984      1.017     -0.097      0.923      -2.091       1.894
# ar.L2         -0.1254      0.513     -0.244      0.807      -1.131       0.880
# ma.L1          0.5243      1.035      0.507      0.612      -1.504       2.552
# ma.L2          0.2662      0.318      0.838      0.402      -0.357       0.889
# ma.L3         -0.2561      0.168     -1.520      0.128      -0.586       0.074
# ma.L4         -0.1312      0.417     -0.315      0.753      -0.948       0.685
# ar.S.L12      -0.9986      0.309     -3.229      0.001      -1.605      -0.393
# ar.S.L24      -0.7177      0.205     -3.493      0.000      -1.120      -0.315
# ma.S.L12       0.0244      0.692      0.035      0.972      -1.332       1.381
# ma.S.L24      -0.2766      0.626     -0.442      0.659      -1.504       0.950
# ma.S.L36      -0.6364      0.469     -1.357      0.175      -1.555       0.282
# ma.S.L48      -0.0521      0.157     -0.331      0.740      -0.360       0.256
# sigma2         9.2798      5.010      1.852      0.064      -0.539      19.099
# ===================================================================================
# Ljung-Box (Q):                       31.35   Jarque-Bera (JB):               221.76
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.79   Skew:                            -1.39
# Prob(H) (two-sided):                  0.42   Kurtosis:                         8.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Predictions vs. Observed:

# %% [markdown]
# ## Gather Exogenous Variables

# %%
ELS_rates = pd.read_csv('data/ELS_rates.csv', index_col = 'date')

# %% [markdown]
# ### Train Test Split Exogenous Variables

# %% [markdown]
# ### Perform Lasso Regression

# %%
lasso_reg(ELS_rates)
# Out:
# The R-score of the Lasso Regression is: 0.8939007612743599
#
# usd1mtd156n      -0.000000
# mortgage30us     -0.000000
# mortgage15us     -0.000000
# dcpf3m           -0.000000
# cpn3m            -0.000000
# dcpf1m           -0.000000
# aaa              -0.000000
# baa              -0.000000
# dff              -0.000000
# flexsc           -0.000000
# t10y2y           -0.000000
# t10y3m           -0.000000
# tedrate          -0.000000
# t10yff           -0.000000
# t5yff            -0.000000
# tb6smffm         -0.000000
# usd3mtd156n      -0.000000
# usd12md156n      -0.000000
# eur1wkd156n      -0.000000
# mprime           -0.000000
# tb3ms            -0.000000
# dtb6             -0.000000
# dgs10            -0.000000
# dgs3mo           -0.000000
# dexuseu           0.000000
# dexchus          -0.000000
# dexusuk          -0.000000
# dexsius          -0.000000
# nasdaqcom         0.005112
# willreitind       0.004831
# willlrgcap       -0.001561
# willsmlcap        0.000154
# vxdcls            0.095614
# stlfsi           -0.000000
# nfci              0.000000
# h8b3094ncba      -0.000028
# bc0dcbw027nbog    0.016392
# casdcbw027nbog   -0.012646
# cildcbw027nbog   -0.016684
# dpsdcbw027nbog    0.008969
# rhedcbw027nbog   -0.000000
# clsacbw027nbog    0.040936
# dpsacbw027nbog   -0.007005
# relacbw027nbog    0.027800
# rheacbw027nbog   -0.052777
# tlaacbw027nbog   -0.007433
# tlbacbw027nbog   -0.006824
# totci             0.033358
# usepuindxd        0.024110
# wlemuindxd       -0.020843
# emvfincrises      0.000000
# stlppm           -0.000000
# dtype: float64
#
# Lasso picked 19 variables and eliminated the other 33 variables

# %% [markdown]
# ### Select significant exogenous features from Lasso Regression

# %%
ELS_rates_train = ELS_rates[:'2018']
ELS_rates_test = ELS_rates['2018':]

# %%
exog_train = ELS_rates_train[['vxdcls', 'clsacbw027nbog', 'totci', 'relacbw027nbog', 'usepuindxd', 'bc0dcbw027nbog', 'rheacbw027nbog']]

# %%
exog_test = ELS_rates_test[['vxdcls', 'clsacbw027nbog', 'totci', 'relacbw027nbog', 'usepuindxd', 'bc0dcbw027nbog', 'rheacbw027nbog']]

# %%
exog_train.shape, exog_test.shape
# Out:
# ((215, 7), (25, 7))

# %%
arima_model = sm.tsa.statespace.SARIMAX(ELS_train,
                                        exog = exog_train,
                                        order = (2,1,2),
                                        seasonal_order = (2,1,2,12),
                                        enforce_stationarity = False,
                                        enforce_invertability = False,
                                        trend = 't')
results = arima_model.fit()
print(f'Summary: {results.summary()}')
print()
print('Diagnostics: ')
results.plot_diagnostics(figsize = (15,8))
plt.show()
# Out:
# Summary:                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                mid   No. Observations:                  215
# Model:             SARIMAX(2, 1, 2)x(2, 1, 2, 12)   Log Likelihood                -434.072
# Date:                            Mon, 10 Feb 2020   AIC                            902.143
# Time:                                    14:14:34   BIC                            955.945
# Sample:                                02-01-2000   HQIC                           923.967
#                                      - 12-01-2017
# Covariance Type:                              opg
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# drift             -0.0003      0.001     -0.271      0.787      -0.002       0.002
# vxdcls            -0.3898      0.103     -3.794      0.000      -0.591      -0.188
# clsacbw027nbog    -0.0316      0.023     -1.389      0.165      -0.076       0.013
# totci             -0.0319      0.038     -0.850      0.395      -0.106       0.042
# relacbw027nbog     0.0007      0.023      0.029      0.977      -0.045       0.047
# usepuindxd        -0.0145      0.010     -1.459      0.144      -0.034       0.005
# bc0dcbw027nbog     0.0298      0.017      1.733      0.083      -0.004       0.063
# rheacbw027nbog    -0.1421      0.115     -1.231      0.218      -0.368       0.084
# ar.L1              0.7381      1.436      0.514      0.607      -2.077       3.553
# ar.L2             -0.2717      0.343     -0.792      0.428      -0.944       0.400
# ma.L1             -0.1743      1.445     -0.121      0.904      -3.007       2.658
# ma.L2              0.0077      0.591      0.013      0.990      -1.150       1.166
# ar.S.L12          -0.6706      0.255     -2.632      0.008      -1.170      -0.171
# ar.S.L24          -0.3297      0.100     -3.284      0.001      -0.526      -0.133
# ma.S.L12          -0.2900      0.265     -1.096      0.273      -0.809       0.229
# ma.S.L24          -0.4279      0.262     -1.636      0.102      -0.941       0.085
# sigma2             8.9614      0.887     10.103      0.000       7.223      10.700
# ===================================================================================
# Ljung-Box (Q):                       50.37   Jarque-Bera (JB):               571.88
# Prob(Q):                              0.13   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.84   Skew:                            -1.57
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#
# Diagnostics:

# %%
predictions = results.get_prediction(start = pd.to_datetime('2015-01-01'), end = pd.to_datetime('2020-01-01'), dynamic=False, exog = exog_test)
pred_conf = predictions.conf_int()
    
#Plot observed values
ax = ELS['2000-02-01':].plot(label='observed', figsize = (15,5))

#Plot predicted values
predictions.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9, color = 'darkblue', style = '--')

#Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='lightblue', alpha=.7)

#Set axes labels
ax.set_xlabel('Year')
ax.set_ylabel('Mid Price')
plt.legend(loc = 'best')
plt.title(f'Mid Price Over Time')
plt.tight_layout()
plt.show()
